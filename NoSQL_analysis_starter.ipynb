# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene':  20}
fields = {"BusinessName": 1}
results = list(establishments.find(query, fields))
# Use count_documents to display the number of documents in the result
establishments.count_documents({'scores.Hygiene': 20})

# Display the first document in the results using pprint
pprint(db.establishments.find_one(query))
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('654eafba9511cf8a735da39b'),
#  'geocode': {'langitude': None,
#              'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
results_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(results_df))


# Display the first 10 rows of the DataFrame
results_df.head(10)
# Out:
# Rows in DataFrame:  41
#                         _id               BusinessName
# 0  654eafba9511cf8a735da39b        The Chase Rest Home
# 1  654eafba9511cf8a735da71d                 Brenalwood
# 2  654eafba9511cf8a735daa26              Melrose Hotel
# 3  654eafba9511cf8a735dac16              Seaford Pizza
# 4  654eafba9511cf8a735dac25              Golden Palace
# 5  654eafba9511cf8a735db5c2           Ashby's Butchers
# 6  654eafba9511cf8a735db7e4  South Sea Express Cuisine
# 7  654eafbb9511cf8a735dcd11              Golden Palace
# 8  654eafbb9511cf8a735dd155             The Tulip Tree
# 9  654eafbb9511cf8a735dd968                      F & S

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'AddressLine3':{'$in': ["London"]}, 'RatingValue': 4|5}
results = list(establishments.find(query))

# Use count_documents to display the number of documents in the result
establishments.count_documents({'AddressLine3':{'$in': ["London"]}, 'RatingValue':  4 |5})

# # Display the first document in the results using pprint
pprint(db.establishments.find_one(query))


####NOTE: No establishments returned with London as the local authority. But many did return with London as the address line 3. I assumed this was a mistake.
# Out:
# {'AddressLine1': '75 Woolwich Road',
#  'AddressLine2': 'Abbey Wood',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'The Croft Day Nursery',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4645.185333904148,
#  'FHRSID': 329113,
#  'LocalAuthorityBusinessID': '03260/0075/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE2 0DY',
#  'RatingDate': '2019-09-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('654eafbb9511cf8a735df374'),
#  'geocode': {'langitude': None,
#              'latitude': Decimal128('51.482981'),
#              'longitude': Decimal128('0.136519')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/329113',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert the result to a Pandas DataFrame
results_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(results_df))


# Display the first 10 rows of the DataFrame
results_df.head(10)
# Out:
# Rows in DataFrame:  650
#                         _id   FHRSID  ChangesByServerID  \
# 0  654eafbb9511cf8a735df374   329113                  0
# 1  654eafbb9511cf8a735df4d5  1402880                  0
# 2  654eafbb9511cf8a735df57f  1262185                  0
# 3  654eafbb9511cf8a735df6e9   687040                  0
# 4  654eafbb9511cf8a735df6fa   610394                  0
# 5  654eafbb9511cf8a735df756  1109051                  0
# 6  654eafbb9511cf8a735df77d  1385124                  0
# 7  654eafbb9511cf8a735df858   669331                  0
# 8  654eafbb9511cf8a735df867   486711                  0
# 9  654eafbb9511cf8a735df878   357629                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0         03260/0075/0/000                              The Croft Day Nursery
# 1              21/00281/CP  Independent Catering Management At Dulverton P...
# 2              20/00155/CP                            Chestnuts Kiosk Limited
# 3         03190/0014/0/000                                    Brownes Chemist
# 4         03190/0008/0/000                                       A W Foodhall
# 5              19/00026/CP                      BP Thamesmead Service Station
# 6                    14474                    Alexander McLeod Primary School
# 7         01530/2001/2/000                           Sporting Club Thamesmead
# 8         02390/4000/1/000                                   Falcon Harvester
# 9         00000/0000/8/957                        Euroville Convenience Store
#
#                 BusinessType  BusinessTypeID        AddressLine1  \
# 0            Caring Premises               5    75 Woolwich Road
# 1  School/college/university            7845    Dulverton School
# 2    Restaurant/Cafe/Canteen               1  Lesnes Abbey Lodge
# 3          Retailers - other            4613   14-16 Wilton Road
# 4          Retailers - other            4613       8 Wilton Road
# 5          Retailers - other            4613     Service Station
# 6  School/college/university            7845      Fuchsia Street
# 7          Pub/bar/nightclub            7843   30 Bayliss Avenue
# 8          Pub/bar/nightclub            7843  Lingfield Crescent
# 9          Retailers - other            4613  66 Kimmeridge Road
#
#       AddressLine2 AddressLine3  ...             LocalAuthorityWebSite  \
# 0       Abbey Wood       London  ...          http://www.bexley.gov.uk
# 1   Dulverton Road       London  ...          http://www.bexley.gov.uk
# 2         New Road       London  ...          http://www.bexley.gov.uk
# 3       Abbey Wood       London  ...          http://www.bexley.gov.uk
# 4       Abbey Wood       London  ...          http://www.bexley.gov.uk
# 5  Harrow Manorway       London  ...          http://www.bexley.gov.uk
# 6                        London  ...  http://www.royalgreenwich.gov.uk
# 7       Thamesmead       London  ...          http://www.bexley.gov.uk
# 8           Eltham       London  ...          http://www.bexley.gov.uk
# 9       Mottingham       London  ...         http://www.bromley.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0     food.safety@bexley.gov.uk
# 1     food.safety@bexley.gov.uk
# 2     food.safety@bexley.gov.uk
# 3     food.safety@bexley.gov.uk
# 4     food.safety@bexley.gov.uk
# 5     food.safety@bexley.gov.uk
# 6  health@royalgreenwich.gov.uk
# 7     food.safety@bexley.gov.uk
# 8     food.safety@bexley.gov.uk
# 9           food@bromley.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 8  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.136519, 'latitude': 51.482981,...
# 1  {'longitude': 0.0809898, 'latitude': 51.435490...
# 2  {'longitude': 0.120351999998093, 'latitude': 5...
# 3  {'longitude': 0.121521, 'latitude': 51.49034, ...
# 4  {'longitude': 0.121087, 'latitude': 51.490312,...
# 5  {'longitude': 0.12143100053072, 'latitude': 51...
# 6  {'longitude': 0.113689996302128, 'latitude': 5...
# 7  {'longitude': 0.128059, 'latitude': 51.507002,...
# 8  {'longitude': 0.079815, 'latitude': 51.459253,...
# 9  {'longitude': 0.046526, 'latitude': 51.426916,...
#
#       Distance NewRatingPending  \
# 0  4645.185334            False
# 1  4645.469911            False
# 2  4645.644355            False
# 3  4646.002131            False
# 4  4646.016925            False
# 5  4646.116317            False
# 6  4646.144905            False
# 7  4646.375351            False
# 8  4646.383453            False
# 9  4646.414896             True
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {'geocode.latitude': {'$gte':latitude-degree_search, '$lte':latitude+degree_search}, 
         'geocode.longitude': {'$gte': longitude-degree_search, '$lte': longitude+degree_search},
         'RatingValue': 5}
sort = [('score.Hygiene', 1)]
limit = 5

# Print the results
results = list(establishments.find(query).sort(sort).limit(limit))
pprint(results)
# Out:
# [{'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('654eafbb9511cf8a735dfbfa'),
#   'geocode': {'langitude': None,
#               'latitude': Decimal128('51.4873437'),
#               'longitude': Decimal128('0.09208')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Manor Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.9740101340385,
#   'FHRSID': 695241,
#   'LocalAuthorityBusinessID': 'PI/000179088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('654eafbb9511cf8a735dfc14'),
#   'geocode': {'langitude': None,
#               'latitude': Decimal128('51.481517791748'),
#               'longitude': Decimal128('0.0859939977526665')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('654eafbb9511cf8a735dfbcf'),
#   'geocode': {'langitude': None,
#               'latitude': Decimal128('51.4871482849121'),
#               'longitude': Decimal128('0.0924199968576431')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '152 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'TIWA N TIWA African Restaurant Ltd',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4646.930146257832,
#   'FHRSID': 1069652,
#   'LocalAuthorityBusinessID': 'PI/000206841',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2020-10-24T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('654eafbb9511cf8a735dfba7'),
#   'geocode': {'langitude': None,
#               'latitude': Decimal128('51.4870351'),
#               'longitude': Decimal128('0.0927429')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1069652',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('654eafbb9511cf8a735dfbdd'),
#   'geocode': {'langitude': None,
#               'latitude': Decimal128('51.4875335693359'),
#               'longitude': Decimal128('0.0925370007753372')},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %%
# Convert result to Pandas DataFrame
results_df = pd.DataFrame(results)
results_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  654eafbb9511cf8a735dfbfa   694609                  0
# 1  654eafbb9511cf8a735dfc14   695241                  0
# 2  654eafbb9511cf8a735dfbcf   695223                  0
# 3  654eafbb9511cf8a735dfba7  1069652                  0
# 4  654eafbb9511cf8a735dfbdd  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000178842                              Iceland
# 3             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2  Retailers - supermarkets/hypermarkets            7840
# 3                Restaurant/Cafe/Canteen               1
# 4                         Mobile caterer            7846
#
#                                         AddressLine1 AddressLine2  \
# 0                    130 - 132 Plumstead High Street
# 1               Plumstead Manor School Old Mill Road
# 2                    144 - 146 Plumstead High Street
# 3                          152 Plumstead High Street
# 4  Restaurant And Premises 107A Plumstead High St...
#
#   AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 2    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 4    Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4  health@royalgreenwich.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.09208, 'latitude': 51.4873437,...
# 1  {'longitude': 0.0859939977526665, 'latitude': ...
# 2  {'longitude': 0.0924199968576431, 'latitude': ...
# 3  {'longitude': 0.0927429, 'latitude': 51.487035...
# 4  {'longitude': 0.0925370007753372, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4646.965635            False
# 1  4646.974010            False
# 2  4646.946071            False
# 3  4646.930146            False
# 4  4646.955931            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

match_query ={'$match': {'scores.Hygiene': 0}}

group_query = {'$group': {'_id':"$LocalAuthorityName", 'count': { '$sum': 1 }} }

sort_values = {'$sort': { 'count': -1 }}

pipeline = [match_query, group_query, sort_values]

results = list(establishments.aggregate(pipeline))

# Count the number of results
print(len(results))

# Display the results
pprint(results)
# Out:
# 55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542},
#  {'_id': 'Colchester', 'count': 498},
#  {'_id': 'Tunbridge Wells', 'count': 491},
#  {'_id': 'Folkestone and Hythe', 'count': 480},
#  {'_id': 'Eastbourne', 'count': 478},
#  {'_id': 'Hastings', 'count': 464},
#  {'_id': 'Bromley', 'count': 460},
#  {'_id': 'Ashford', 'count': 427},
#  {'_id': 'Havering', 'count': 397},
#  {'_id': 'Dartford', 'count': 383},
#  {'_id': 'Braintree', 'count': 382},
#  {'_id': 'Basildon', 'count': 362},
#  {'_id': 'Gravesham', 'count': 339},
#  {'_id': 'Tonbridge and Malling', 'count': 325},
#  {'_id': 'Thurrock', 'count': 313},
#  {'_id': 'Barking and Dagenham', 'count': 301},
#  {'_id': 'Canterbury City', 'count': 298},
#  {'_id': 'Brentwood', 'count': 285},
#  {'_id': 'Castle Point', 'count': 281},
#  {'_id': 'Harlow', 'count': 274},
#  {'_id': 'Uttlesford', 'count': 251},
#  {'_id': 'Lewes', 'count': 250},
#  {'_id': 'Sevenoaks', 'count': 223},
#  {'_id': 'Maldon', 'count': 197},
#  {'_id': 'East Hertfordshire', 'count': 189},
#  {'_id': 'Rochford', 'count': 187},
#  {'_id': 'Redbridge', 'count': 182},
#  {'_id': 'Epping Forest', 'count': 180},
#  {'_id': 'East Suffolk', 'count': 159},
#  {'_id': 'Waltham Forest', 'count': 110},
#  {'_id': 'Babergh', 'count': 97},
#  {'_id': 'Wealden', 'count': 93},
#  {'_id': 'Rother', 'count': 80},
#  {'_id': 'Lewisham', 'count': 65},
#  {'_id': 'Tandridge', 'count': 42},
#  {'_id': 'City of London Corporation', 'count': 28},
#  {'_id': 'Ipswich', 'count': 21},
#  {'_id': 'Tower Hamlets', 'count': 9},
#  {'_id': 'North Hertfordshire', 'count': 6},
#  {'_id': 'Mid Sussex', 'count': 5},
#  {'_id': 'Broxbourne', 'count': 1},
#  {'_id': 'North Norfolk', 'count': 1},
#  {'_id': 'Reading', 'count': 1},
#  {'_id': 'Dorset', 'count': 1},
#  {'_id': 'Sunderland', 'count': 1},
#  {'_id': 'Kensington and Chelsea', 'count': 1}]

# %%
# Convert the result to a Pandas DataFrame
results_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(results_df))


# Display the first 10 rows of the DataFrame
results_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542

# %%
#
